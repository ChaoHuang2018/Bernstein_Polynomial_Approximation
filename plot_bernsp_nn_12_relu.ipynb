# %%
import bernsp as bp
import numpy as np
import sympy as sp
from network_parser import nn_controller, nn_controller_details
from numpy import pi, tanh, array, dot
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
f = nn_controller('nn_12_relu', 'ReLU')
f_details = nn_controller_details('nn_12_relu', 'ReLU')
x_sym = sp.symbols('x:'+str(2))

# %%
f(np.array([0.7, 0.9]))
# Out:
# array([[-4.]])

# %% [markdown]
# ## Box: [[0.5, 0.6], [-0.95, -0.85]]
# ## Degree Bound: [1, 1]

# %%
box = [[0.5, 0.6], [-0.95, -0.85]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
ax.scatter(x_data, y_data, f_data, label='nn')
ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.legend()
plt.xlabel('x0')
plt.ylabel('x1')
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))
# Out:
# diff on vertex: [0]
# diff on vertex: [4.44089209850063e-16]
# diff on vertex: [-4.44089209850063e-16]
# diff on vertex: [-4.44089209850063e-16]

# %% [markdown]
# ## Box: [[0.7, 0.9], [0.7, 0.9]]
# ## Degree Bound: [1, 1]

# %%
box = [[0.7, 0.9], [0.7, 0.9]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
ax.scatter(x_data, y_data, f_data, label='nn')
ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.legend()

input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))
# Out:
# diff on vertex: [-3.55271367880050e-15]
# diff on vertex: [-3.55271367880050e-15]
# diff on vertex: [-3.55271367880050e-15]
# diff on vertex: [-3.55271367880050e-15]

# %% [markdown]
# ## Box: [[0.1, 0.9], [0.1, 0.9]]
# ## Degree Bound: [1, 1]

# %%
box = [[0.1, 0.9], [0.1, 0.9]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
ax.scatter(x_data, y_data, f_data, label='nn')
ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0f798658d3e2> in <module>()
#      25     poly = b
#      26     for j in range(2):
# ---> 27         poly = poly.subs(x_sym[j], input[j])
#      28     p_data[i] = poly
#      29     # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))
#
# /home/jiameng/packages/Bernsp/lib/python3.6/site-packages/sympy/core/basic.py in subs(self, *args, **kwargs)
#     928             rv = self
#     929             for old, new in sequence:
# --> 930                 rv = rv._subs(old, new, **kwargs)
#     931                 if not isinstance(rv, Basic):
#     932                     break
#
# /home/jiameng/packages/Bernsp/lib/python3.6/site-packages/sympy/core/basic.py in _subs(self, old, new, **hints)
#    1042         rv = self._eval_subs(old, new)
#    1043         if rv is None:
# -> 1044             rv = fallback(self, old, new)
#    1045         return rv
#    1046
#
# /home/jiameng/packages/Bernsp/lib/python3.6/site-packages/sympy/core/basic.py in fallback(self, old, new)
#    1015                     continue
#    1016                 arg = arg._subs(old, new, **hints)
# -> 1017                 if not _aresame(arg, args[i]):
#    1018                     hit = True
#    1019                     args[i] = arg
#
# /home/jiameng/packages/Bernsp/lib/python3.6/site-packages/sympy/core/basic.py in _aresame(a, b)
#    1795
#    1796     """
# -> 1797     from .function import AppliedUndef, UndefinedFunction as UndefFunc
#    1798     for i, j in zip_longest(preorder_traversal(a), preorder_traversal(b)):
#    1799         if i != j or type(i) != type(j):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Box: [[0.1, 0.9], [0.1, 0.9]]
# ## Degree Bound: [3, 3]

# %%
box = [[0.1, 0.9], [0.1, 0.9]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [3, 3], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
ax.scatter(x_data, y_data, f_data, label='nn')
ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))

# %% [markdown]
# ## Diff on Box: [[0.5, 0.6], [-0.95, -0.85]]
# ## Degree Bound: [1, 1]

# %%
box = [[0.5, 0.6], [-0.95, -0.85]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
# ax.scatter(x_data, y_data, f_data, label='nn')
# ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.scatter(x_data, y_data, f_data - p_data, label='diff between nn and poly')
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))

# %%
box = [[0.3, 0.4], [-1.2, -0.9]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
# ax.scatter(x_data, y_data, f_data, label='nn')
# ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.scatter(x_data, y_data, f_data - p_data, label='diff between nn and poly')
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))

# %%
box = [[0.15, 0.25], [-1.2, -0.8]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
# ax.scatter(x_data, y_data, f_data, label='nn')
# ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.scatter(x_data, y_data, f_data - p_data, label='diff between nn and poly')
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))

# %%
box = [[-0.55, -0.5], [1.2, 1.25]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.001
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
# ax.scatter(x_data, y_data, f_data, label='nn')
# ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.scatter(x_data, y_data, f_data - p_data, label='diff between nn and poly')
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))

# %%
f = nn_controller('nn_12_relu_tanh', 'ReLU_tanh')
f_details = nn_controller_details('nn_12_relu_tanh', 'ReLU_tanh')
x_sym = sp.symbols('x:'+str(2))
box = [[0.7, 0.9], [0.7, 0.9]]

sample_range = np.array(box)

b, _, _ = bp.nn_poly_approx_bernstein(f, x_sym, [1, 1], box, 0)

dense = 0.01
x = np.arange(sample_range[0][0], sample_range[0][1], dense)
y = np.arange(sample_range[1][0], sample_range[1][1], dense)
X, Y = np.meshgrid(x, y)
inputs = np.array([X.flatten(), Y.flatten()]).T

num_data = inputs.shape[0]
x_data = np.zeros(num_data)
y_data = np.zeros(num_data)
f_data = np.zeros(num_data)
p_data = np.zeros(num_data)


for i in range(num_data):
    input = inputs[i]
    x_data[i] = input[0]
    y_data[i] = input[1]
    f_data[i] = f(input)[0]
    poly = b
    for j in range(2):
        poly = poly.subs(x_sym[j], input[j])
    p_data[i] = poly
    # print('poly: {}, nn: {}'.format(p_data[i], f_data[i]))

plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.cla()
ax.scatter(x_data, y_data, f_data, label='nn')
ax.scatter(x_data, y_data, p_data, label='bernstein_poly', alpha=0.5)
ax.legend()
input = np.zeros(2)
for i in range(2):
    for j in range(2):
        input[0] = box[0][i]
        input[1] = box[1][j]
        f_res = f(input)[0]
        poly_res = b
        for indx in range(2):
            poly_res = poly_res.subs(x_sym[indx], input[indx])
        print('diff on vertex: {}'.format(f_res-poly_res))
# Out:
# diff on vertex: [-8.88178419700125e-16]
# diff on vertex: [-2.66453525910038e-15]
# diff on vertex: [-3.99680288865056e-15]
# diff on vertex: [-3.55271367880050e-15]

# %%
f = nn_controller('nn_12_relu_tanh', 'ReLU_tanh')
f_details = nn_controller_details('nn_12_relu_tanh', 'ReLU_tanh')

# %%
f(np.array([0.7, 0.9]))
# Out:
# array([[-3.9017127]])
